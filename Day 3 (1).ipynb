# %% [markdown]
# # Data structure
#
# List

# %%
list1=[11,12,13,14,15]

# %%
list1.append(16)

# %%
list1
# Out:
# [11, 12, 13, 14, 15, 16]

# %%
list1.append(17)

# %%
list1
# Out:
# [11, 12, 13, 14, 15, 16, 17]

# %%
listfruit=["Grapes" , "Banana", "Apple", "Papaya"]

# %%
listfruit
# Out:
# ['Grapes,Banana', 'Apple', 'Papaya']

# %%
listfruit.append("Kiwi")

# %%
listfruit
# Out:
# ['Grapes,Banana', 'Apple', 'Papaya', 'Kiwi']

# %%
len(listfruit)
# Out:
# 4

# %%
listfruit[0]
# Out:
# 'Grapes'

# %%
listfruit[1]
# Out:
# 'Banana'

# %%
listfruit[3]
# Out:
# 'Papaya'

# %%
listfruit[0:2]
# Out:
# ['Grapes', 'Banana']

# %%
listfruit[1:4]
# Out:
# ['Banana', 'Apple', 'Papaya']

# %%
listfruit[-1]
# Out:
# 'Papaya'

# %% [markdown]
# Insert something inside list

# %%
listfruit.insert(1,"watermelon")

# %%
listfruit
# Out:
# ['Grapes', 'watermelon', 'Banana', 'Apple', 'Papaya']

# %%
list1.insert(3,900)

# %%
list1
# Out:
# [11, 12, 13, 900, 14, 15, 16, 17]

# %%
len(listfruit)
# Out:
# 5

# %% [markdown]
# Sort/Reverse

# %%
listfruit.sort()

# %%
listfruit
# Out:
# ['Apple', 'Banana', 'Grapes', 'Papaya', 'watermelon']

# %%
listfruit.reverse()

# %%
listfruit
# Out:
# ['watermelon', 'Papaya', 'Grapes', 'Banana', 'Apple']

# %%
listfruit.index("Papaya")
# Out:
# 1

# %%
listfruit.index("Grapes")
# Out:
# 2

# %% [markdown]
# newlist

# %%
 newlist=["watermelon" , "dragonfruit"]

# %%
newlist
# Out:
# ['watermelon', 'dragonfruit']

# %%
newlist.extend(fruitlist)

# %%
newlist
# Out:
# ['watermelon',
#  'dragonfruit',
#  'watermelon',
#  'Papaya',
#  'Grapes',
#  'Banana',
#  'Apple']

# %% [markdown]
# POP operation

# %%
listfruit.pop()
# Out:
# 'Apple'

# %%
listfruit
# Out:
# ['watermelon', 'Papaya', 'Grapes', 'Banana']

# %%
len(listfruit)
# Out:
# 4

# %% [markdown]
# remove

# %%
listfruit.remove("Grapes")

# %%
listfruit
# Out:
# ['watermelon', 'Papaya', 'Banana']

# %% [markdown]
# Clear

# %%
listfruit.clear()

# %%
listfruit
# Out:
# []

# %%
listfruit.append("Mango")

# %%
listfruit
# Out:
# ['Mango']

# %%
listfruit.append("Banana")

# %%
listfruit
# Out:
# ['Mango', 'Banana']

# %%
del listfruit

# %%
listfruit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3712/1855494486.py in <module>
# ----> 1 listfruit
#
# NameError: name 'listfruit' is not defined

# %%
 planetlist=["mercury","venus"]

# %%
planetlist
# Out:
# ['mercury', 'venus']

# %%
planetlist.append('Earth')

# %%
planetlist
# Out:
# ['mercury', 'venus', 'Earth']

# %%
planetlist.extend(['Mars','Jupiter','saturn'])

# %%
planetlist.append('neptune')

# %%
planetlist
# Out:
# ['mercury',
#  'venus',
#  'Earth',
#  'Mars',
#  'Jupiter',
#  'saturn',
#  ['Neptune'],
#  'Neptune',
#  'Neptune',
#  'neptune']

# %%
len(planetlist)
# Out:
# 10

# %%
planetlist[0]
# Out:
# 'mercury'

# %%
planetlist[3]
# Out:
# 'Mars'

# %%
planetlist[0:4]
# Out:
# ['mercury', 'venus', 'Earth', 'Mars']

# %%
planetlist[-1]
# Out:
# 'neptune'

# %%
planetlist[-4:-1]
# Out:
# [['Neptune'], 'Neptune', 'Neptune']

# %%
planetlist
# Out:
# ['mercury',
#  'venus',
#  'Earth',
#  'Mars',
#  'Jupiter',
#  'saturn',
#  ['Neptune'],
#  'Neptune',
#  'Neptune',
#  'neptune']

# %%
planetlist.pop()
# Out:
# 'neptune'

# %%
planetlist
# Out:
# ['mercury',
#  'venus',
#  'Earth',
#  'Mars',
#  'Jupiter',
#  'saturn',
#  ['Neptune'],
#  'Neptune',
#  'Neptune']

# %%
planetlist.pop(3)
# Out:
# 'Mars'

# %%
planetlist
# Out:
# ['mercury',
#  'venus',
#  'Earth',
#  'Jupiter',
#  'saturn',
#  ['Neptune'],
#  'Neptune',
#  'Neptune']

# %%
len(planetlist)
# Out:
# 8

# %%
planetlist1=['jupiter','mercury','Earth','Neptune','saturn']

# %%
planetlist1
# Out:
# ['jupiter', 'mercury', 'Earth', 'Neptune', 'saturn']

# %%
planetlist1.sort()

# %%
planetlist1
# Out:
# ['Earth', 'Neptune', 'jupiter', 'mercury', 'saturn']

# %%
planetlist1.reverse()

# %%
planetlist1
# Out:
# ['saturn', 'mercury', 'jupiter', 'Neptune', 'Earth']

# %%
planetlist1.insert(3,'pluto')

# %%
planetlist1
# Out:
# ['saturn', 'mercury', 'jupiter', 'pluto', 'Neptune', 'Earth']

# %%
planetlist1.index('pluto')
# Out:
# 3

# %%
planetlist1.pop()
# Out:
# 'Earth'

# %%
planetlist1
# Out:
# ['saturn', 'mercury', 'jupiter', 'pluto', 'Neptune']

# %%
planetlist1.pop(4)
# Out:
# 'Neptune'

# %%
planetlist1
# Out:
# ['saturn', 'mercury', 'jupiter', 'pluto']

# %%
planetlist1.remove('saturn')

# %%
planetlist1
# Out:
# ['mercury', 'jupiter', 'pluto']

# %%
planetlist1.append('uranus')

# %%
planetlist1
# Out:
# ['mercury', 'jupiter', 'pluto', 'uranus']

# %% [markdown]
# Mutable properties of list

# %%
planetlist[1]
# Out:
# 'Jupiter'

# %%
planetlist[1]="sun"

# %%
planetlist
# Out:
# ['Earth', 'sun', 'mercury', 'saturn', ['Neptune'], 'Neptune', 'Neptune']

# %% [markdown]
# In clear, list is present without any data only internal list is removed

# %%
planetlist.clear()

# %%
planetlist
# Out:
# []

# %% [markdown]
# deleting list leads to remove entire list, nothing can be found

# %%
del planetlist

# %%
planetlist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11628/3676854626.py in <module>
# ----> 1 planetlist
#
# NameError: name 'planetlist' is not defined

# %%
numlist=[100,200,300,400,500,600]

# %%
numlist
# Out:
# [100, 200, 300, 400, 500, 600]

# %%
numlist[5]
# Out:
# 600

# %%
numlist[4]
# Out:
# 500

# %%
numlist[4]=345

# %%
numlist
# Out:
# [100, 200, 300, 400, 345, 600]

# %% [markdown]
# list element are mutable it can be changed after the creation

# %%
del numlist

# %%
numlist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11628/3803243408.py in <module>
# ----> 1 numlist
#
# NameError: name 'numlist' is not defined

# %% [markdown]
# del fuction can delete the entire list
