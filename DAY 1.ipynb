# %% [markdown]
# # Python is a easy open sourse language

# %% [markdown]
# Modulous operator

# %%
2**3
# Out:
# 8

# %%
print('Hello world')
# Out:
# Hello world

# %%
a=10

# %%
a
# Out:
# 10

# %%
b=5

# %%
b
# Out:
# 5

# %%
a*b
# Out:
# 50

# %%
a-b
# Out:
# 5

# %%
a+b
# Out:
# 15

# %%
c=a+b

# %%
print("c=",c)
# Out:
# c= 5

# %%
c
# Out:
# 15

# %%
print("c=",c)
# Out:
# c= 5

# %%
c=a-b

# %%
c
# Out:
# 5

# %%
b=10

# %%
c=5

# %%
d=b+c

# %%
d
# Out:
# 15

# %%
print("d=",d)
# Out:
# d= 15

# %%
print("the value of d=",d)
# Out:
# the value of d= 15

# %%
len("james")
# Out:
# 5

# %%
city="newyork"

# %%
city
# Out:
# 'newyork'

# %%
len("city")
# Out:
# 4

# %%
len(city)
# Out:
# 7

# %%
city="newyork"

# %%
city
# Out:
# 'newyork'

# %%
len(city)
# Out:
# 7

# %% [markdown]
# # string concetenation

# %% [markdown]
# Area of rectangle

# %%
length=50
breadth=6
area=length*breadth
print(area)
print('area of rectangle=',area) 
print("area of rectagle with length=",length, "and breadth=",breadth,"is",area)
# Out:
# 300
# area of rectangle= 300
# area of rectagle with length= 50 and breadth= 6 is 300

# %%
print("area of rectangle with length=",length,"and breadth=",breadth,"is",area)
# Out:
# area of rectangle with length= 50 and breadth= 6 is 300

# %%
print("area of rectangle with length=",length,"and","breadth=",breadth,"is",area)
# Out:
# area of rectangle with length= 50 and breadth= 6 is 200.96

# %%
print("area of rectangle with length=",length ,"and ", "breadth=",breadth,"is ",area)
# Out:
# area of rectangle with length= 50 and  breadth= 6 is  300

# %%
print("area of rectangle with length=",length,"and ", "breadth=",breadth,"is",area)
# Out:
# area of rectangle with length= 50 and  breadth= 6 is 300

# %% [markdown]
# area of circle

# %%
pi=3.14
radius=8
area=pi*(radius**2)
print("the area of circle is ",area)
# Out:
# the area of circle is  200.96

# %% [markdown]
# Typecasting

# %%
a=60

# %%
type(a)
# Out:
# int

# %%
fees=888.50

# %%
type(fees)
# Out:
# float

# %%
j=True

# %%
type(j)
# Out:
# bool

# %%
country="india"

# %%
type(country)
# Out:
# str

# %%
Lenght=50

# %%
breadth=10

# %%
area=length*breadth

# %%
print(area)
# Out:
# 500

# %%
print("area of rectangle with length=",length,"and","breadth=",breadth,"is",area)
# Out:
# area of rectangle with length= 50 and breadth= 10 is 500

# %%
10>7
# Out:
# True

# %%
56<6
# Out:
# False

# %%
10==10
# Out:
# True

# %%
10!=9
# Out:
# True

# %%
a=15
b=20
c=a+b
print("c=",c)
# Out:
# c= 35

# %%
print(c)
# Out:
# 35

# %%
print('c')
# Out:
# c

# %%
print("c=",c)
# Out:
# c= 35

# %%
a=90
b=30
c=1
d=a*b-c
print("d=",d)
# Out:
# d= 2699

# %%
p=30
n=33
a=8
d=p+n+a
print("d=",d)
# Out:
# d= 71

# %%
print(d)
# Out:
# 71
