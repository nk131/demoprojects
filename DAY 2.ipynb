# %%
country=input("enter any country name")
# Out:
# enter any country nameindia

# %%
country
# Out:
# 'india'

# %%
number1=input("enter any nunber")
# Out:
# enter any nunber87

# %%
number1
# Out:
# '87 '

# %%
number2=input("enter any number")
# Out:
# enter any number100

# %%
number2
# Out:
# '100'

# %% [markdown]
# Adding the values

# %%
number1=int(input("enter any number"))
# Out:
# enter any number87

# %%
number1
# Out:
# 87

# %%
number2=int(input("enter any number"))
# Out:
# enter any number100

# %%
number2
# Out:
# 100

# %%
number1+number2
# Out:
# 187

# %%
length=20
breadth=10
area=length*breadth
print(area)
# Out:
# 200

# %%
list1=(1,2,3,4,5)

# %%
list1
# Out:
# (1, 2, 3, 4, 5)

# %%
list2=(11,12,13,14,15,16,17,18)

# %%
list2
# Out:
# (11, 12, 13, 14, 15, 16, 17, 18)

# %%
list3=(10,20,30,40,50)

# %%
list3
# Out:
# (10, 20, 30, 40, 50)

# %%
list4=(98.4,98.5,98.6)

# %%
list4
# Out:
# (98.4, 98.5, 98.6)

# %%
list5=('matrix','avenger')

# %%
list5
# Out:
# ('matrix', 'avenger')

# %%
list6=(13,69.4,"matrix","avenger")

# %%
list6
# Out:
# (13, 69.4, 'matrix', 'avenger')

# %%
complist=["laptop","mouse","printer"]

# %%
complist
# Out:
# ['laptop', 'mouse', 'printer']

# %%
complist[0]
# Out:
# 'laptop'

# %% [markdown]
# slicing

# %%
complist[0:2]
# Out:
# ['laptop', 'mouse']

# %%
complist[0:]
# Out:
# ['laptop', 'mouse', 'printer']

# %%
complist[:]
# Out:
# ['laptop', 'mouse', 'printer']

# %%
complist[:2]
# Out:
# ['laptop', 'mouse']

# %%
complist
# Out:
# ['laptop', 'mouse', 'printer']

# %%
complist[-2]
# Out:
# 'mouse'
