# %% [markdown]
# # Tuples

# %%
t1=(1,2,3,4,5,6)

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t2=(4.5,7,8,'A',True,False)

# %%
t2
# Out:
# (4.5, 7, 8, 'A', True, False)

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t1[0]
# Out:
# 1

# %%
t1[2]
# Out:
# 3

# %%
t1[4]
# Out:
# 5

# %%
t1[4]=989
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19944/2067236525.py in <module>
# ----> 1 t1[4]=989
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# tuple can't allow to change the internal element after creation

# %% [markdown]
# # Dictonary

# %%
dict1={'id':101,'Name':'Andrew','Age':10}

# %%
dict1
# Out:
# {'id': 101, 'Name': 'Andrew', 'Age': 10}

# %%
dict1.keys()
# Out:
# dict_keys(['id', 'Name', 'Age'])

# %%
dict1.values()
# Out:
# dict_values([101, 'Andrew', 10])

# %%
dict1.items()
# Out:
# dict_items([('id', 101), ('Name', 'Andrew'), ('Age', 10)])

# %%
mobiledict={"mobid":1,"mobilebrand":"apple","mobileprice":70000}

# %%
mobiledict
# Out:
# {'mobid': 1, 'mobilebrand': 'apple', 'mobileprice': 70000}

# %%
mobiledict['mobilebrand']
# Out:
# 'apple'

# %%
mobiledict['mobileprice']
# Out:
# 70000

# %%
mobiledict['mobid']
# Out:
# 1

# %%
mobiledict['mobileprice']=85000

# %%
mobiledict['mobileprice']
# Out:
# 85000

# %% [markdown]
# in dictionary one can change internal values

# %%
mobiledict.keys()
# Out:
# dict_keys(['mobid', 'mobilebrand', 'mobileprice'])

# %%
mobiledict.values()
# Out:
# dict_values([1, 'apple', 85000])

# %%
mobiledict.items()
# Out:
# dict_items([('mobid', 1), ('mobilebrand', 'apple'), ('mobileprice', 85000)])
